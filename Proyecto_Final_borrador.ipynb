# %%
import random
import time
from IPython.display import clear_output
from IPython.display import HTML

#Registro de jugadores.
global nombre
global puntuacion
jugador = {}
puntuacion = {}

def mostrar_menu_principal():
    html_content = """
   <div style="color: pink; font-size: 48px; font-weight: 800; text-align: center; font-family: monospace">
    ¡Acertijos matemáticos!
   </div>
   """
# Mostrar el contenido HTML en la celda de texto
    display(HTML(html_content))
    while True:
      print("\033[1;36m"+"¡Bienvenidos a los acertijos matemáticos!" "\033[1;31m"+"\nSeleccione una opción:" "\033[1;32m"+"\n1. Agregar jugadores." "\033[1;33m"+"\n2. Verificar puntuaciones" "\033[1;34m"+"\n3. Jugar" "\033[1;35m"+"\n4. Salir del juego:")
      principal = int(input("\n"))
      time.sleep(4)
      clear_output()
      if principal == 4:
       print("\033[0;34m"+"Gracias por jugar")
       time.sleep(4)
       clear_output()
       break

      if principal == 1 or principal == 2 or principal == 3:
       print("\033[1;37;46m"+"Ingresa el nombre del jugador: ")
       nombre = input("\n").capitalize()
       time.sleep(4)
       clear_output()

      if principal == 1:
        registrar(nombre)
      elif principal == 2:
        puntuaciones(nombre)
      elif principal == 3:
        juego(jugador)
      else:
       print("\033[1;35m"+"Seleccione una opción válida")
       time.sleep(4)
       clear_output()
       mostrar_menu_principal()


def registrar(nombre):
  if nombre not in jugador:
      jugador[nombre] = []
      print("\033[3;31m"+'Jugador {} registrado exitosamente.'.format(nombre))
      time.sleep(4)
      clear_output()
      jugador[nombre].append(nombre)
  else:
    print("\033[0;36m"+"Nombre de jugador ocupado. \nPor favor elija otra opción \nVolviendo a menú principal...")
    time.sleep(4)
    clear_output()



#Verificar puntuaciones.
def puntuaciones(nombre):
     print("\033[3;34m"+"Seleccione lo que desee hacer: \n1. Verificar mi puntuacion. \n2. Ver ranking.")
     menu = int(input("\n"))
     time.sleep(4)
     clear_output()
     if menu == 1:
      print("\033[1;37;44m"+"Ingrese el nombre del jugador a verificar la puntuación: ")
      nom = input("\n").capitalize()
      time.sleep(4)
      clear_output()
      res = nom in jugador
      if res == False:
       print("\033[1;31m"+'Ingrese el nombre de manera correcta')
       time.sleep(4)
       clear_output()
       puntuaciones(nombre)

      if jugador[nombre]:
        print("\033[1;37;41m"+'Jugador: {} \nPuntuación: {}'.format(nombre, puntuacion))
        time.sleep(5)
        clear_output()
      else:
        print("\033[1;31m"+"El jugador {} no tiene puntuaciones registradas. \n Volviendo al menú principal...")
        time.sleep(4)
        clear_output()
     elif menu == 2:
        ranking = sorted(jugador[nombre]['puntuaciones'])
        print("\033[1;37;44m"+"El ranking es: \n", ranking)
        time.sleep(4)
        clear_output()
     else:
      print("\033[1;30;47m"+"No hay jugadores registrados \nVolviendo a menú principal...")
      time.sleep(4)
      clear_output()


#Juego
def menu_juego():
  print("\033[1;32m"+"1. Siguiente acertijo")
  print("\033[1;31m"+"2. Terminar partida")
  opcion = int(input("Elige una opción: "))
  time.sleep(5)
  clear_output()
  return opcion


def juego(jugador):
    global errores
    global puntuacion
    intentos_totales = 3  # Intentos totales para toda la partida

    acertijos_correctos = 0
    intentos_restantes = intentos_totales  # Inicializar intentos para toda la partida

    for i, acertijo in enumerate(acertijos_partida):
        while intentos_restantes > 0:
            print(acertijo["pregunta"])
            respuesta_usuario = float(input("Ingresa tu respuesta: "))
            time.sleep(3)
            clear_output()

            if respuesta_usuario == acertijo["respuesta"]:
                print("\033[1;32m"+"¡Correcto! :)")
                time.sleep(3)
                clear_output()
                if acertijo["dificultad"] == "fácil":
                    puntuacion += 10
                elif acertijo["dificultad"] == "media":
                    puntuacion += 20
                elif acertijo["dificultad"] == "difícil":
                    puntuacion += 30
                acertijos_correctos += 1
                break
            else:
                print("\033[1;31m"+"Incorrecto :(")
                errores += 1
                intentos_restantes -= 1
                print("\033[3;30m"+f"Te quedan {intentos_restantes} intentos.")
                time.sleep(5)
                clear_output()

        if errores >= intentos_totales:
            print("\033[3;30m"+"Has alcanzado el límite de errores. La partida ha terminado.")
            break
            time.sleep(3)
            clear_output()

        if i < 8:
            opcion_menu_juego = menu_juego()
            if opcion_menu_juego == 2:
                print("\033[3;30m"+"Terminando la partida...")
                time.sleep(5)
                clear_output()
                break


    if acertijos_correctos == 8:
        if errores == 0:
            puntuacion *= 2
        elif errores == 1:
            puntuacion += 30
        elif errores == 2:
            puntuacion += 25
    elif acertijos_correctos == 7:
        puntuacion += 20
    elif acertijos_correctos == 6:
        puntuacion += 15
    elif acertijos_correctos == 5:
        puntuacion += 10
    elif acertijos_correctos == 4:
        puntuacion -= 5
    elif acertijos_correctos == 3:
        puntuacion -= 10
    elif acertijos_correctos == 2:
        puntuacion -= 15
    elif acertijos_correctos == 1:
        puntuacion = 1

    print("\033[1;37;42m"+f"Acertaste {acertijos_correctos} acertijos. Tu puntuación final es {puntuacion}.")
    jugador["puntuaciones"].append(puntuacion)
    time.sleep(5)
    clear_output()

    return errores, puntuacion

# Inicialización de acertijos y sublistas por dificultad
acertijos = [
    {"pregunta": "\033[1;34m" + "Hay 15 amigos jugando manita caliente, 4 se salen del juego y después 3 más entran, 2 más se vuelven a salir y 4 más se acercan a jugar, ¿cuántas manos hay en total?", "respuesta": 31, "dificultad": "fácil"},
    {"pregunta": "\033[1;34m" + "Pan, pan y pan, pan y pan y medio, cuatro medios panes, y tres panes y medio. ¿Cuántos panes hay en total?", "respuesta": 6, "dificultad": "fácil"},
    {"pregunta": "\033[1;34m" + "El padre se comió 1/6 parte de un pastel. El hermano mayor se comió 1/5 de lo que quedaba. La madre se comió 1/4 del resto. Llegó el perro y se comió 1/3 del pastel restante. El vecino se comió la mitad de lo que quedaba. ¿Qué fracción del pastel quedó al final? Exprésalo en decimales.", "respuesta": 0.25, "dificultad": "fácil"},
    {"pregunta": "\033[1;34m" + "En casa tengo varios animales. Todos son gatos menos dos, todos son perros menos dos, y todos son canarios menos dos. ¿Cuántos animales de cada tengo?", "respuesta": 1, "dificultad": "fácil"},
    {"pregunta": "\033[1;34m" + "Si yo tengo 19, mi mejor amigo Heriberto tiene 21, mis amigos Cristian, Laura y Saul tienen la misma edad que yo, mi amigo Santiago y Alex tienen 20, ¿qué numero hacen nuestras edades sumadas, si luego le quitas la mitad y después le sumas 680.5?", "respuesta": 137, "dificultad": "fácil"},
    {"pregunta": "\033[1;34m" + "José tiene 4 gallinas, las cuales ponen 16 huevos en 2 meses, ¿cuántos huevos pondrán en medio año?", "respuesta": 96, "dificultad": "fácil"},
    {"pregunta": "\033[1;34m" + "Un pastor tiene 18 ovejas, y se le mueren todas menos 10. ¿Cuántas ovejas le quedan al pastor?", "respuesta": 10, "dificultad": "fácil"},
    {"pregunta": "\033[1;34m" + "4 amigos salieron a jugar a Recórcholis, Rosita tiene 80 pesos, Juan tiene el triple, Lola tiene lo mismo que Juan y Heriberto tiene la mitad de lo que tiene lola, ¿cuánto dinero llevaron entre todos?", "respuesta": 680, "dificultad": "fácil"},
    {"pregunta": "\033[1;34m" + "En la fiesta hay 15 figuras, 4 triángulos, 2 rectángulos, 3 decágonos, 2 romboides, 1 eneágono y 1 círculo, ¿cuántos lados tienen todas las figuras?", "respuesta": 57, "dificultad": "fácil"},
    {"pregunta": "\033[1;34m" + "Si Juan tiene 30 años y su hermano tiene 18 ¿Cuántos años tendrá su hermano si Juan tiene 53 años?", "respuesta": 41, "dificultad": "fácil"},
    {"pregunta": "\033[1;34m" + "Encuentra la solución entera para x en la ecuación (2x^2) – 3x -2 = 0", "respuesta": 2, "dificultad": "media"},
    {"pregunta": "\033[1;34m" + "Encuentra la derivada de la función f(x) = 3x-2", "respuesta": 3, "dificultad": "media"},
    {"pregunta": "\033[1;34m" + "En una ciudad, la población se duplica cada 10 años. Si la población actual es de 64,000, ¿cuántos años pasaron desde que la población era de 16,000?", "respuesta": 20, "dificultad": "media"},
    {"pregunta": "\033[1;34m" + "Si ahora son las 3:20 p.m., ¿cuántos grados habrán girado las manecillas del reloj cuando sea 4:30 p.m.?", "respuesta": 75, "dificultad": "media"},
    {"pregunta": "\033[1;34m" + "Si 5 personas pueden pintar 5 habitaciones en 5 horas, ¿cuántas horas tomaría para que 10 personas pinten 10 habitaciones?", "respuesta": 10, "dificultad": "media"},
    {"pregunta": "\033[1;34m" + "Un topo pequeño tarda 9 horas en cavar un metro de galería bajo tierra. Un topo mediano tarda 6 horas y un topo grande tarda 4 horas y media. Si juntamos a los 3 topos, ¿Cuánto horas tardarán en cavar la galería de un metro?", "respuesta": 2, "dificultad": "media"},
    {"pregunta": "\033[1;34m" + "Un oso recorre 26 km en dirección hacia el sur. Después, camina otros 19 km en dirección este. Por último, hace 57 km más hacia el norte, ¿cuántos kilómetros ha recorrido?", "respuesta": 102, "dificultad": "media"},
    {"pregunta": "\033[1;34m" + "Tienes 5 conejos, 40 cerdos y 20 caballos en una granja. Si deseas llamar caballos a los cerdos, ¿cuál es el número total de caballos que tienes?", "respuesta": 20, "dificultad": "media"},
    {"pregunta": "\033[1;34m" + "En el calendario tenemos que son 365 días y 12 meses para darnos cuenta de que tenemos un año, cuántos meses tienen 30 días, sin contar año bisiesto.", "respuesta": 4, "dificultad": "media"},
    {"pregunta": "\033[1;34m" + "¡Hola soy dodecágono!, ¿cuántos lados tengo si estoy multiplicándome al cubo?", "respuesta": 1782, "dificultad": "media"},
    {"pregunta": "\033[1;34m" + "Un cubo tiene 6 caras, cada cara tiene 6 cuadrados. ¿Cuántos cuadrados hay en total en el cubo?", "respuesta": 216, "dificultad": "difícil"},
    {"pregunta": "\033[1;34m" + "Un número es divisible por 2 si su última cifra es par. ¿Cuántos números divisibles por 2 hay entre 1 y 100?", "respuesta": 50, "dificultad": "difícil"},
    {"pregunta": "\033[1;34m" + "Un número es divisible por 3 si la suma de sus cifras es divisible por 3. ¿Cuántos números divisibles por 3 hay entre 1 y 100?", "respuesta": 33, "dificultad": "difícil"},
    {"pregunta": "\033[1;34m" + "En una serie de números consecutivos del 1 al 100, algunos números han sido eliminados. La suma de los números restantes es 5050. Faltan dos números, considerando que uno de ellos es el 52 ¿Cuál es el número que faltan?", "respuesta": 51, "dificultad": "difícil"},
    {"pregunta": "\033[1;34m" + "Juan tiene el doble de la edad que tenía su hermana cuando él tenía la edad que su hermana tiene ahora. Si la hermana de Juan tiene 10 años, ¿cuántos años tiene Juan?", "respuesta": 15, "dificultad": "difícil"},
    {"pregunta": "\033[1;34m" + "Encuentra la lógica en la siguiente secuencia y determina cuál es el próximo número: 2, 12, 1112, 3112, 132112,…", "respuesta": 1113122112, "dificultad": "difícil"},
    {"pregunta": "\033[1;34m" + "Tienes una caja fuerte con un candado de combinación de 3 números. Cada número es del 0 al 9. ¿Cuántas combinaciones posibles hay si no puedes repetir los números?", "respuesta": 720, "dificultad": "difícil"},
    {"pregunta": "\033[1;34m" + "Encuentra el próximo número en la secuencia de Fibonacci: 0, 1, 1, 2, 3, 5, 8, 13, ...", "respuesta": 21, "dificultad": "difícil"},
    {"pregunta": "\033[1;34m" + "Piensa en un número. Si duplicas ese número y luego le sumas 8, y después divides el resultado por 2, obtendrás 10. ¿Cuál es el número original?", "respuesta": 7, "dificultad": "difícil"},
    {"pregunta": "\033[1;34m" + "¿Cuál es el límite de la secuencia cuando n tiende al infinito: (n^2)/((n^2)+n)?", "respuesta": 1, "dificultad": "difícil"},
]


# Sublistas de acertijos por dificultad
acertijos_faciles = [acertijo for acertijo in acertijos if acertijo["dificultad"] == "fácil"]
acertijos_medios = [acertijo for acertijo in acertijos if acertijo["dificultad"] == "media"]
acertijos_dificiles = [acertijo for acertijo in acertijos if acertijo["dificultad"] == "difícil"]

# Juntar las sublistas en una lista para la partida
acertijos_partida = random.sample(acertijos_faciles, 3) + random.sample(acertijos_medios, 3) + random.sample(acertijos_dificiles, 2)

# Inicializar las variables fuera de la función juego
errores = 0
puntuacion = 0

# Llamada a la función juego
jugador = {"puntuaciones": []}

mostrar_menu_principal()
